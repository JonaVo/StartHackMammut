# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np
import math


f_vertical = h5py.File("./data/vertical/40587108-e1a8-56ae-8c7f-1853f009b7c6_raw.h5", "r" )
#print (list(f_overhang.keys())

acc_LH = np.array(f_vertical["acc_LH"])
acc_RH = np.array(f_vertical["acc_RH"])
pres_LH = np.array(f_vertical["pres_LH"])
pres_RH = np.array(f_vertical["pres_RH"])
climbing_raw = np.array(f_vertical["climbing"])
#print (*pres_RH)
print (acc_LH)
# Out:
# [(1.61425979e+09, 0.78078555, 0.70754112,  0.29737236)
#  (1.61425979e+09, 0.81083219, 0.67654061,  0.28067977)
#  (1.61425979e+09, 0.80549592, 0.59805331,  0.29098988) ...
#  (1.61426031e+09, 0.65406866, 0.0997303 , -0.73616338)
#  (1.61426031e+09, 0.66102017, 0.08749309, -0.73469782)
#  (1.61426031e+09, 0.66558768, 0.08911501, -0.73771876)]

# %%
#from scipy import stats
#df_cleaned = df[(np.abs(stats.zscore(df["Left_AP"])) < 3)]

# %%
def extract(lst, index): 
    return np.array([item[index] for item in lst])

# %%
relevantStamps = []

for is_climbing in climbing_raw:
    if is_climbing[1]!= 0:
        relevantStamps.append(is_climbing[0])

print (len(relevantStamps))

acc_RH_relevant= []

for dat in acc_RH:
    if dat[0] in relevantStamps :
        acc_RH_relevant.append(dat)

#print (acc_LH_relevant)
# Out:
# 3174

# %%
print(relevantStamps[0])
# Out:
# 1614259836.5

# %%
plt.figure(figsize=(15,5))
plt.scatter(extract(acc_RH_relevant, 0), extract(acc_RH_relevant, 1), s=10)
plt.show()
#linke Hand alle relevanten Moves

# %%
#running average for left Hand
nForConvolution = 25
tmp1 = np.convolve(extract(acc_RH_relevant,1), np.ones(nForConvolution)/nForConvolution, mode='valid')
tmp2 = np.convolve(extract(acc_RH_relevant,2), np.ones(nForConvolution)/nForConvolution, mode='valid')
tmp3 = np.convolve(extract(acc_RH_relevant,3), np.ones(nForConvolution)/nForConvolution, mode='valid')

tmp4 = 0

acc_RH_relevant_conv =[]
for i in range(len(acc_RH_relevant[:-(nForConvolution-1)])):
    
    acc_RH_relevant_conv.append([acc_RH_relevant[i][0],tmp1[i], tmp2[i], tmp3[i], ((math.sqrt(tmp1[i]**2+tmp2[i]**2+tmp3[i]**2))-1)**2])
    
plt.figure(figsize=(15,5))
plt.scatter(extract(acc_RH_relevant_conv, 0), extract(acc_RH_relevant_conv, 4), s=10)
plt.show()

# %%
nForConvolution = 25
tmp1 = np.convolve(extract(acc_RH_relevant_conv,1), np.ones(nForConvolution)/nForConvolution, mode='valid')
tmp2 = np.convolve(extract(acc_RH_relevant_conv,2), np.ones(nForConvolution)/nForConvolution, mode='valid')
tmp3 = np.convolve(extract(acc_RH_relevant_conv,3), np.ones(nForConvolution)/nForConvolution, mode='valid')

tmp4 = 0


for i in range(len(acc_RH_relevant_conv[:-(nForConvolution-1)])):
    
    acc_RH_relevant_conv[i] = [acc_RH_relevant_conv[i][0],tmp1[i], tmp2[i], tmp3[i], ((math.sqrt(tmp1[i]**2+tmp2[i]**2+tmp3[i]**2))-1)**2]
    
plt.figure(figsize=(15,5))
plt.scatter(extract(acc_RH_relevant_conv, 0), extract(acc_RH_relevant_conv, 4), s=10)
plt.show()

# %%
for i in range(len(acc_RH_relevant_conv)):
    
    acc_RH_relevant_conv[i][0] = acc_RH_relevant_conv[i][0]
    acc_RH_relevant_conv[i][0] = np.around(acc_RH_relevant_conv[i][0],2)

# %%
plt.figure(figsize=(15,5))
plt.scatter(extract(acc_RH_relevant_conv, 0), extract(acc_RH_relevant_conv, 4), s=10)
plt.show()

# %%
for i in range(len(acc_RH_relevant_conv)):
    if acc_RH_relevant_conv[i][4] <= 0.0125:
        acc_RH_relevant_conv[i][4] = 0

# %%
plt.figure(figsize=(15,5))
plt.scatter(extract(acc_RH_relevant_conv, 0), extract(acc_RH_relevant_conv, 4), s=10)
plt.show()

# %%
moveTime = []
for i in range(len(acc_RH_relevant_conv)-2):
    if (acc_RH_relevant_conv[i][4]!= 0 and acc_RH_relevant_conv[i+1][4]!= 0 and acc_RH_relevant_conv[i+1][4]!= 0):
        moveTime.append (acc_RH_relevant_conv[i+1])

# %%
plt.figure(figsize=(15,5))
plt.scatter(extract(moveTime, 0), extract(moveTime, 4), s=10)
plt.show()

# %%
diffs= []
for i in range(len(moveTime)-1):
    diffs.append(moveTime[i+1][0] - moveTime[i][0])

# %%
plt.figure(figsize=(15,5))
plt.scatter(extract(moveTime, 0)[:-1], diffs, s=10)
plt.show()

# %%
print (sum(diffs)/len(diffs))
# Out:
# 0.12549180329823104

# %%
startTimes = []
startTimes.append(moveTime[0][0])
endTimes = []
meanOfdiffs= sum(diffs)/len(diffs)
for i in range(len(diffs)):
    if (diffs[i]>= 8*meanOfdiffs):
                 endTimes.append(moveTime[i][0])
                 startTimes.append(moveTime[i+1][0])
startTimes = startTimes[:-1]

# %%
#offset in seconds

from datetime import datetime
from datetime import timedelta


offset = 36966/1000 -2.5 #+(11.674-13.880)
FirstAccTimestamp = 1.61425979e+09

# %%
def convertToVideoTime(timeData):
    deltaToStart = datetime.fromtimestamp(timeData)- (datetime.fromtimestamp(FirstAccTimestamp))
    #print (deltaToStart)
    videoTime = deltaToStart- timedelta(seconds = offset)
    #return video seconds
    return videoTime

# %%
startTimesInVideo = []
endTimesInVideo = []

for i in range(len(endTimes)):
    endTimesInVideo.append(convertToVideoTime(endTimes[i]).total_seconds())
for i in range(len(startTimes)):
    startTimesInVideo.append(convertToVideoTime(startTimes[i]).total_seconds())

# %%
print (startTimesInVideo)
print (endTimesInVideo)
# Out:
# [13.754, 16.554, 23.694, 29.634, 33.574, 38.094, 42.914, 46.974, 51.974, 59.454, 62.594, 67.054, 71.614]
# [14.694, 17.394, 24.134, 30.714, 34.454, 39.214, 43.594, 48.114, 52.974, 60.574, 63.434, 67.714, 72.574]

# %%
print(endTimesInVideo+(np.ones(len(endTimesInVideo))*0.5))
# Out:
# [15.194 17.894 24.634 31.214 34.954 39.714 44.094 48.614 53.474 61.074
#  63.934 68.214 73.074]
